# %% [markdown]
# ## Introduction

# %% [markdown]
# Copris is a constraint programming DSL embedded in Scala.
# This page provides some example [Jupyter](http://jupyter.org/) notebooks of [Copris](http://bach.istc.kobe-u.ac.jp/copris/) running on [Almond](https://almond.sh) Scala kernel.
#
# -   [notebooks/intro-en.ipynb](notebooks/intro-en.ipynb) (English)
# -   [notebooks/intro-ja.ipynb](notebooks/intro-ja.ipynb) (Japanese)
#
# Original GitHub site is [https://github.com/tamura70/copris-examples](https://github.com/tamura70/copris-examples)
