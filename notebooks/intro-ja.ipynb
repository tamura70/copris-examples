// %% [markdown]
// ## はじめに

// %% [markdown]
// Scala上の制約プログラミングシステム [Copris](http://bach.istc.kobe-u.ac.jp/copris/) による制約プログラミング入門．
// 詳細は以下を参照．
//
// -   [Coprisによる制約プログラミング入門](http://bach.istc.kobe-u.ac.jp/copris/docs/intro-ja.html)

// %% [markdown]
// ## 始めての利用

// %%
// The first line is needed only for Jupyter notebooks.
// The jar file is appended to the classpath.
import $cp.`copris-all-v2-3-1.jar`

import jp.kobe_u.copris._
import dsl._

init
int('x, 1, 15)
int('y, 1, 15)
int('z, 1, 15)
add('x + 'y + 'z === 15)
add('x + 'y * 5 + 'z * 10 === 90)

// %%
println(csp)
println(csp.variables)
println(csp.bools)
println(csp.dom)
println(csp.constraints)

// %%
show

// %%
find

// %%
println(solution)
